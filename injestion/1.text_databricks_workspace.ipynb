# %%
from pyspark.sql.functions import *

# %%
df = spark.read.format("csv")\
        .option("header", True)\
            .option("inferSchema", True)\
                .load("/Volumes/workspace/default/e-commerce/olist_customers_dataset.csv")

# %%
df.explain()

# %%
df.count()

# %%
df.limit(5).display()

# %%
df_selected = df.select("customer_city", "customer_id", "customer_state")

# %%
df_selected.explain("extended")

# %%
df_selected.explain("formatted")
