-- %%
SELECT 
    *
FROM gold.fact_sales oi
JOIN silver.orders  o
ON oi.order_id = o.order_id
WHERE oi.order_id = '00310b0c75bb13015ec4d82d341865a4'
LIMIT 5

-- SELECT 
--     order_status,
--     COUNT(order_status)
-- FROM silver.orders
-- GROUP BY order_status
